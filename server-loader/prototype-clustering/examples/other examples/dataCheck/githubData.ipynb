# %%
from requests.auth import HTTPBasicAuth
import requests
import pandas as pd
import json

# %%
url = '../data/IMMA/citizenInteractions.csv'

# GAM
url = '../data/GAM/users.csv'
url = '../data/GAM/artworks.json'
url = '../data/GAM/clean_data/artwors.csv'
url = '../data/GAM/clean_data/users.csv'
url = '../data/GAM/clean_data/interactions.csv'
url = '../data/GAM/clean_data/EmoTag1200-scores.csv'

# HECHT
url = '../data/HECHT/implicit_values.csv'
url = '../data/HECHT/demographic.csv'
url = '../data/HECHT/open.csv'
url = '../data/HECHT/forces_open.csv'
url = '../data/HECHT/open_communities.csv'

url = '../data/HECHT/AllData15122021.xlsx'
url = '../data/HECHT/dataset_15122021.csv'

# IMMA
url = '../data/IMMA/artworks_IMMA.json'
url = '../data/IMMA/response_IMMA.json'
url = '../data/IMMA/citizenInteractions.csv'

# MNCN
url = '../data/MNCN/semana_ciencia_2021.csv'
url = '../data/MNCN/user_profiles.csv'
url = '../data/MNCN/user_profiles_grouped.csv'

url = '../data/MNCN/Sessions/sesion_jueves_11.json'

# Prado
url = '../data/prado-dataset/emotions_graphs.json'
url = '../data/prado-dataset/users_emotions.json'
url = '../data/prado-dataset/Prado_emotions.csv'

url = '../data/MNCN/user_profiles.csv'

# sd23
url = '../data/HECHT/dataset_15122021.csv'

url = 'gam.json'

# %%
interactions_df = pd.read_json(url)
#interactions_df = pd.read_excel(url)
# interactions_df = pd.read_json(url)
#interactions_df = pd.read_csv(url,sep=';') # fpr dataset_15122021.csv

interactions_df
# Out:
#       _id    @id     Data modifica  \
# 0   35476  35476  2018-04-17 17:11
# 1   40157  40157  2019-08-28 16:01
# 2   35260  35260  2018-11-19 10:12
# 3   38593  38593  2018-06-08 12:24
# 4   39426  39426  2020-11-30 17:20
# ..    ...    ...               ...
# 95  39648  39648  2020-11-30 17:07
# 96  39190  39190  2018-12-13 11:49
# 97  35461  35461  2018-12-20 12:44
# 98  39076  39076  2018-10-02 12:41
# 99  41423  41423  2020-12-11 16:44
#
#                                             title Inventario  \
# 0                      Ritratto del figlio Pierre     P/1367
# 1                          Word Movie fluxfilm#29
# 2                                  Roma (Il muro)     P/1704
# 3                            9 Minutes fluxfilm#6
# 4        Piccola composizione (Fantome incantato)     P/1373
# ..                                            ...        ...
# 95  Anticoli sole a picco (Paesaggio di Anticoli)     P/1114
# 96                  La trecciaiola (La trecciaia)     P/1273
# ...

# %%
interactions_df.head(20)
# Out:
#       _id    @id     Data modifica  \
# 0   35476  35476  2018-04-17 17:11
# 1   40157  40157  2019-08-28 16:01
# 2   35260  35260  2018-11-19 10:12
# 3   38593  38593  2018-06-08 12:24
# 4   39426  39426  2020-11-30 17:20
# 5   35232  35232  2018-12-05 11:14
# 6   37536  37536  2017-05-10 16:30
# 7   39417  39417  2020-11-30 17:32
# 8   40145  40145  2019-08-08 18:07
# 9   39915  39915  2019-06-06 12:20
# 10  35410  35410  2018-11-19 10:02
# 11  40158  40158  2019-08-28 16:06
# 12  38856  38856  2018-08-09 13:31
# 13  39209  39209  2018-12-12 13:23
# 14  39195  39195  2018-12-13 11:55
# 15  35313  35313  2019-01-15 10:41
# 16  35475  35475  2015-12-21 13:18
# 17  39403  39403  2020-11-30 17:48
# 18  39349  39349  2020-12-11 16:28
# 19  39216  39216  2018-12-13 12:08
#
#                                                 title Inventario  \
# 0                          Ritratto del figlio Pierre     P/1367
# 1                              Word Movie fluxfilm#29
# ...

# %%
interactions_df.tail(30)
# Out:
#       _id    @id     Data modifica  \
# 70  39208  39208  2018-12-12 12:37
# 71  35523  35523  2020-12-11 17:14
# 72  38590  38590  2018-06-07 15:27
# 73  39192  39192  2018-12-11 12:46
# 74  35244  35244  2019-01-24 12:33
# 75  35347  35347  2015-12-18 12:10
# 76  39392  39392  2020-12-11 16:05
# 77  39366  39366  2020-12-11 16:18
# 78  35308  35308  2018-11-13 11:40
# 79  35338  35338  2018-11-19 12:37
# 80  35383  35383  2018-11-26 11:58
# 81  35329  35329  2015-12-18 12:14
# 82  35440  35440  2018-11-19 10:04
# 83  41265  41265  2020-07-31 10:42
# 84  35351  35351  2018-11-23 09:53
# 85  35471  35471  2015-12-21 12:37
# 86  39384  39384  2020-12-11 16:11
# 87  39644  39644  2020-11-30 17:12
# 88  35437  35437  2015-12-21 12:23
# 89  35296  35296  2018-11-13 10:22
# 90  35453  35453  2018-11-19 13:12
# 91  35256  35256  2018-11-21 13:01
# 92  39365  39365  2020-12-11 16:19
# 93  35349  35349  2018-11-23 09:49
# 94  35289  35289  2019-01-15 10:34
# ...

# %%
interactions_df.columns
# Out:
# Index(['_id', '@id', 'Data modifica', 'title', 'Inventario', 'Collezione',
#        'Soggetto', 'author', 'year', 'Materiale e Tecnica', 'Dimensioni',
#        'Definizione', 'dc:source', 'image', 'dc:description', 'Note Blind',
#        '_datasetid', '_timestamp', '_timestamp_year', '_timestamp_month',
#        '_timestamp_day', '_timestamp_hour', '_timestamp_minute',
#        '_timestamp_second', '_updated'],
#       dtype='object')

# %%
interactions_df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
len(interactions_df)
# Out:
# 100
