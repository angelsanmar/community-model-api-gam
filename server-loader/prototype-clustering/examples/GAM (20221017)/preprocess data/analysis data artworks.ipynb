# %%
# %load_ext autoreload
# %autoreload 2

# %%
from requests.auth import HTTPBasicAuth
import requests
import pandas as pd
import json

# %%
artworks = pd.read_json('data/GAM_Catalogue_plus.json')
artworks
# Out:
#       _id    @id  DateOfLastModify  \
# 0   35246  35246  2019-01-15 11:52
# 1   35211  35211  2015-12-18 12:50
# 2   35250  35250  2018-12-05 12:24
# 3   35381  35381  2015-12-21 11:39
# 4   35456  35456  2019-01-15 10:59
# 5   35499  35499  2017-04-18 16:33
# 6   35362  35362  2020-11-30 16:19
# 7   35227  35227  2020-12-11 17:05
# 8   35323  35323  2018-04-17 17:06
# 9   35374  35374  2018-11-23 09:54
# 10  35237  35237  2018-11-19 09:58
# 11  35210  35210  2018-11-19 12:23
# 12  35230  35230  2018-04-17 17:02
# 13  35288  35288  2018-11-14 12:47
# 14  39182  39182  2018-12-11 11:01
# 15  35217  35217  2018-11-13 10:07
# 16  39648  39648  2020-11-30 17:07
# 17  39384  39384  2020-12-11 16:11
# 18  35364  35364  2018-11-20 09:40
# 19  39347  39347  2019-01-24 13:28
# 20  35433  35433  2018-11-14 10:27
# 21  35236  35236  2018-12-07 10:47
# 22  41209  41209  2020-06-18 14:29
# 23  35308  35308  2018-11-13 11:40
# 24  39425  39425  2020-11-30 17:21
# ...

# %%
materials = pd.unique(artworks['Materials'])
materials
# Out:
# array(['none', 'burlap, resin', 'sponge, acrylic, cork', 'video',
#        'plaster', 'wax', 'resin, plexiglass', 'marble'], dtype=object)

# %%
materials = pd.unique(artworks['Artist_country'])
materials
# Out:
# array(['Lithuania', 'Italy', 'Greece', 'France', 'Russian Federation',
#        'Austria', 'United Kingdom', 'Germany', 'United States', ''],
#       dtype=object)

# %%
materials = pd.unique(artworks['Artwork_Artistic_Movement'])
materials
# Out:
# array(['Scuola romana', 'Romanticism', 'Art Informel', 'Surrealism',
#        'Plein Air', 'Metaphysical painting', 'Realism', 'Magic realism',
#        'Eclecticism', 'Futurism', 'Avant garde', 'Art Nouveau', 'Verism',
#        'Post-impressionism', 'Abstract art', 'Gruppo Novecento',
#        'Viennese Actionism', 'Divisionism', 'Historical Romanticism',
#        'MAC', 'Art Brut', 'Scapigliatura', 'Op Art', 'Symbolism',
#        'Pop Art', 'Neoclassicism'], dtype=object)
