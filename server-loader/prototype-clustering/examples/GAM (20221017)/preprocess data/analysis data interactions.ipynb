# %%
# %load_ext autoreload
# %autoreload 2

# %%
from requests.auth import HTTPBasicAuth
import requests
import pandas as pd
import json

# %%
interactions = pd.read_json('data/generated/GAM user_interactions mergedArtworks.json')
interactions
# Out:
#          _id   userName          TimeStamps                     Gender_x  \
# 0       None   0bAAwK14                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 2   B3N0HGw4   B3N0HGw4 2022-01-10 17:07:46                      Femmina
# 3       None   BTKF72et                 NaT                         None
# 4   JgevtrSb   JgevtrSb 2022-09-30 11:16:16  Preferisco non specificarlo
# 5   KQTGApjD   KQTGApjD 2022-01-10 16:59:07                      Femmina
# 6   LW3Klzvx   LW3Klzvx 2022-01-10 17:09:19                      Femmina
# 7   LvIeXwcT   LvIeXwcT 2022-01-10 10:53:03  Preferisco non specificarlo
# 8   N72IRgFy   N72IRgFy 2022-01-10 16:23:52                      Maschio
# 9   RQ4a2nIG   RQ4a2nIG 2022-01-10 11:21:12  Preferisco non specificarlo
# 10  Sz5Wx2XD   Sz5Wx2XD 2022-01-10 17:47:27                      Maschio
# 11  WYCImqGm   WYCImqGm 2022-01-10 15:54:48                      Femmina
# ...

# %%
# Check different emotions values
df = interactions.explode(['emotions','plutchik_emotions'])
df[['emotions','plutchik_emotions']]
# Out:
#                                              emotions  \
# 0                                     {'Interest': 1}
# 0   {'Love': 1, 'Fear': 1, 'Sadness': 2, 'Interest...
# 0                              {'Joy': 1, 'Trust': 1}
# 1                              {'Sadness': 0.9014473}
# 1                       {'Anger': 0.6110284300000001}
# ..                                                ...
# 20                                    {'Surprise': 1}
# 20                                                 []
# 21                                        {'Love': 1}
# 22         {'Interest': 0.618530799999999, 'Fear': 1}
# 23                                                 []
#
#                                     plutchik_emotions
# 0   {'anger': 0, 'anticipation': 0, 'disgust': 0, ...
# 0   {'anger': 0, 'anticipation': 0.5, 'disgust': 0...
# 0   {'anger': 0, 'anticipation': 0, 'disgust': 0, ...
# 1   {'anger': 0, 'anticipation': 0, 'disgust': 0, ...
# ...

# %%
df = df.loc[ df['emotions'].str.len() != 0 ]
df = df.loc[ df['plutchik_emotions'].str.len() != 0 ]
df
# Out:
#          _id   userName          TimeStamps                     Gender_x  \
# 0       None   0bAAwK14                 NaT                         None
# 0       None   0bAAwK14                 NaT                         None
# 0       None   0bAAwK14                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 1       None   6rK3p7za                 NaT                         None
# 2   B3N0HGw4   B3N0HGw4 2022-01-10 17:07:46                      Femmina
# 3       None   BTKF72et                 NaT                         None
# 3       None   BTKF72et                 NaT                         None
# 3       None   BTKF72et                 NaT                         None
# ...

# %%
df2 = pd.json_normalize(df['emotions'])
df3 = pd.json_normalize(df['plutchik_emotions'])

# %%
print(len(df2.columns))
print(df2.columns)
# Out:
# 11
# Index(['Interest', 'Love', 'Fear', 'Sadness', 'Joy', 'Trust', 'Anger',
#        'Serenity', 'Anticipation', 'Disgust', 'Surprise'],
#       dtype='object')

# %%
print(len(df3.columns))
print(df3.columns)
# Out:
# 8
# Index(['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness',
#        'surprise', 'trust'],
#       dtype='object')

# %%
list1 = [x.lower() for x in df2.columns]

# %%
set1 = set(list1)
set2 = set(df3.columns)
res = list(set1 - set2)

# %%
print(len(res))
print(res)
# Out:
# 3
# ['interest', 'serenity', 'love']
