# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import json

# %%
#--------------------------------------------------------------------------------------------------------------------------
#
#--------------------------------------------------------------------------------------------------------------------------

# %%
from context import community_module, dao, communityModel
from communityModel.communityModel_notebook import CommunityModelNotebook
from communityModel.dataLoader import DataLoader
from communityModel.inSpiceDataFormatter import InSpiceDataFormatter

# %%
dataLoader = DataLoader()
route = dataLoader.fileRoute("data/new-annotated-stories.json")

# %%
annotated_stories_df = pd.read_json(route)
annotated_stories_df
# Out:
#                               _datasetid                       _id  \
# 0   816c8fb3-6c73-4405-bf71-b1c765c4a79e  633869df947d991ed04cf7f7
# 1   816c8fb3-6c73-4405-bf71-b1c765c4a79e  633865fd947d991ed04cf7de
# 2   816c8fb3-6c73-4405-bf71-b1c765c4a79e  633865ce947d991ed04cf7dc
# 3   816c8fb3-6c73-4405-bf71-b1c765c4a79e  6338649a2df2fd104d686349
# 4   816c8fb3-6c73-4405-bf71-b1c765c4a79e  6338625f758e693b2f1aea9d
# ..                                   ...                       ...
# 95  816c8fb3-6c73-4405-bf71-b1c765c4a79e  62272bca8b5d531b7a287bc6
# 96  816c8fb3-6c73-4405-bf71-b1c765c4a79e  62272dc4aa89621f0d6ce920
# 97  816c8fb3-6c73-4405-bf71-b1c765c4a79e  6227300d925cbb70f01278b4
# 98  816c8fb3-6c73-4405-bf71-b1c765c4a79e  622731a552655f48ae32ca9d
# 99  816c8fb3-6c73-4405-bf71-b1c765c4a79e  622738c2d74ca33e0d61f217
#
#     _timestamp  _timestamp_day  _timestamp_hour  _timestamp_minute  \
# 0   1664641503               1               17                 25
# ...

# %%
dataFormatter = InSpiceDataFormatter()
df = dataFormatter.formatData(annotated_stories_df)
df
# Out:
# dao_db_interaction data
# df4 after merging with artworks
#      index                          _datasetid_x                     _id_x  \
# 0     48.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  6333f4ea13a6b278b06dc2fb
# 1     72.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  63316656c53b9822101176b6
# 2     88.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  62bdd2020af3e135fc5753bc
# 3      NaN                                   NaN                       NaN
# 4      NaN                                   NaN                       NaN
# ..     ...                                   ...                       ...
# 225   61.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  6331f676da21134eb64f76e4
# 226   78.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  632dab3fcfb08e51f124bcef
# 227   79.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  632d5c10719af0778157a991
# 228    4.0  816c8fb3-6c73-4405-bf71-b1c765c4a79e  6338625f758e693b2f1aea9d
# 229    NaN                                   NaN                       NaN
#
# ...

# %%
#--------------------------------------------------------------------------------------------------------------------------
#    Test CM-inSPICE
#--------------------------------------------------------------------------------------------------------------------------

# %%
from dao.dao_json import DAO_json

# %%
dataRoute = dataLoader.fileRoute('data/generated/annotated_stories_merged.json')
perspectiveRoute = dataLoader.fileRoute('perspectives/GAM similar user emotions in similar artworks (iconclass) annotated-stories.json')

# %%
daoJson = DAO_json(dataRoute)
with open(perspectiveRoute + '', 'r', encoding='utf8') as f:
            perspective = json.load(f)

# %%
communityModel = CommunityModelNotebook(perspective, dao = daoJson)

# %%
p = 0.5
communityModel.start(percentageExplainability = p)
# Out:
# dafdsfasdf
# sfdsf
#
#
#                     userName  \
# 0                   0bAAwK14
# 1   61f29227b9936b5c047f362a
# 2                   6rK3p7za
# 3                   B3N0HGw4
# 4                   BTKF72et
# 5                   FVhf7OMw
# 6                   KQTGApjD
# 7                   L11lvHun
# 8                   LW3Klzvx
# 9                   LvIeXwcT
# 10                  N72IRgFy
# 11                  RQ4a2nIG
# 12                  Sz5Wx2XD
# 13                  WsK2A1ab
# 14                  Y0WXF1LR
# 15                 anonymous
# 16                  cBjFhvjx
# 17                  e4aM9WL7
# 18                  fqybaAk8
# 19                  loEoYm9R
# 20                  onDqgFnI
# 21                  ox8G7avH
# 22                  q2BDj1os
# 23                  x2AUnHqw
# 24                  yjlouq5U
#
#                                             artworkId  \
# 0   [35456, 35323, 35230, 35288, 35287, 35225, 39416]
# ...
